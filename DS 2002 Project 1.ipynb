# %% [markdown]
# # Project 1

# %% [markdown]
# ## Instructions

# %% [markdown]
# ETL data processor
# 1. Deliverable: Author a segment of an ETL pipeline that will ingest or process raw data.
# You must also submit a URL to a GitHub repository for your solution. In python you’ll
# need to know how to open files, iterate files, pattern match and output files.
# 2. Benchmarks:
# i. Your data processor should be able to ingest a pre-defined data source and
# perform at least three of these operations:
#     1. Fetch / download / retrieve a remote data file by URL (API call like we did
#     in class), or ingest a local file that you have downloaded from
#     somewhere…like in a CSV format. Suggestions for remote data sources
#     are listed at the end of this document on our Github page as we went
#     through in class.
#     2. Convert the general format and data structure of the data source (from
#     JSON to CSV, from CSV to JSON, from JSON into a SQL database table,
#     etc. I want the option to convert any source to any target. So, if I get a
#     CSV as an input, I want the user to choose an output)
#     3. Modify the number of columns from the source to the destination,
#     reducing or adding columns so that you transform it with something
#     else…you can make up whatever it is…like date changes…or mash up
#     two columns…it’s up to you.
#     4. The converted (new) file should be written to disk (local file) or written to a
#     SQL database like SQL Lite
#     5. Generate a brief summary of the data file ingestion after it has processed
#     and output it to the user including:
#         1. Number of records
#         2. Number of columns
# ii. The processor should produce informative errors should it be unable to complete
# an operation. (Try / Catch with error messages, not file exists…just pick any
# error.)
#
# 3. Grading:
# i.Successful build of the solution that I can run and replicate your results 10
# ii.Functionality that meets all benchmarks – 10 points
# iii.Creativity / Innovation / Quality – 2 points
# iv. Documentation – Describes how to use the data processor and the elements
# that make it operational – 3 points
#
# Publicly-available datasets:
# •	https://www.kaggle.com/datasets
# •	https://data.world/
# •	https://www.data.gov/
# •	https://opendata.charlottesville.org/
# You can Choose/find data from anywhere you like…these are just suggestions.
# Publicly-available APIs:
# • https://docs.github.com/en/rest
# • https://developer.twitter.com/en/docs/twitter-api
# • HUGE LIST: https://github.com/public-apis/public-apis

# %% [markdown]
# ## Code

# %%
# import statements (Directions: Click the "Run" button at the top of the program for the needed import statements)
import json
import csv
import requests
import pandas as pd

# %%
# Taking user input for the zipcode (Directions: 1) Click "Run" 2) Enter a 5-digit integer zipcode 3) Click the enter key
zipcode = input()
# Out:
# 22903

# %%
# Displaying the zipcode Ticker (Directions: Click "Run" to make sure the zipcode is the one you entered)
zipcode
# Out:
# '22903'

# %%
# Creating a header (Directions: Click "Run" so that the header can be built)
header_var = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
# Fetching remote data file by url from api (Directions: 1) Click "Run" to pull a url from the Ticket Master API and create a JSON data variable
url = 'https://app.ticketmaster.com/discovery/v2/events.json?apikey=hFlpdwoseKzCByGogzG3JfCoNGcMYlc5'
query_str = {"postalCode": zipcode}
response = requests.request("GET", url, headers = header_var, params = query_str)
data = response.json()
data
# Out:
# {'_embedded': {'events': [{'name': 'Reba McEntire',
#     'type': 'event',
#     'id': 'vvG17Z9KDKVtwJ',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/reba-mcentire-charlottesville-virginia-03-11-2023/event/01005D3ED3D29CA6',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False}],
#     'sales': {'public': {'startDateTime': '2022-10-07T14:00:00Z',
#       'startTBD': False,
#       'startTBA': False,
#       'endDateTime': '2023-03-12T00:30:00Z'},
#      'presales': [{'startDateTime': '2022-10-04T14:00:00Z',
#        'endDateTime': '2022-10-07T02:00:00Z',
#        'name': 'VIP Packages Presale'},
#       {'startDateTime': '2022-10-04T14:00:00Z',
#        'endDateTime': '2022-10-07T02:00:00Z',
#        'name': 'Reba McEntire Artist Presale'},
#       {'startDateTime': '2022-10-05T14:00:00Z',
#        'endDateTime': '2022-10-07T02:00:00Z',
#        'name': 'Terri Clark Artist Presale'},
#       {'startDateTime': '2022-10-07T14:00:00Z',
#        'endDateTime': '2023-03-02T03:00:00Z',
#        'name': 'VIP Packages Onsale'},
#       {'startDateTime': '2022-10-04T14:00:00Z',
#        'endDateTime': '2022-10-07T02:00:00Z',
#        'name': 'Official Platinum Presale'},
#       {'startDateTime': '2022-10-07T14:00:00Z',
#        'endDateTime': '2023-03-12T01:00:00Z',
#        'name': 'Official Platinum'},
#       {'startDateTime': '2022-10-04T14:00:00Z',
#        'endDateTime': '2022-10-07T02:00:00Z',
#        'name': 'Citi® Cardmember Presale'},
#       {'startDateTime': '2022-10-07T14:00:00Z',
#        'endDateTime': '2023-02-19T03:00:00Z',
#        'name': 'Citi® Cardmember Preferred Tickets'},
#       {'startDateTime': '2022-10-06T14:00:00Z',
#        'endDateTime': '2022-10-07T02:00:00Z',
#        'name': 'Live Nation Presale'},
#       {'startDateTime': '2022-10-06T14:00:00Z',
#        'endDateTime': '2022-10-07T02:00:00Z',
#        'name': 'RADIO/VENUE/LOCAL PRESALE'},
#       {'startDateTime': '2022-10-04T14:00:00Z',
#        'endDateTime': '2023-03-12T00:30:00Z',
#        'name': 'Lower Level Preferred Seating'},
#       {'startDateTime': '2022-10-04T14:00:00Z',
#        'endDateTime': '2023-03-12T00:30:00Z',
#        'name': 'Upper Level Preferred Seating'}]},
#     'dates': {'start': {'localDate': '2023-03-11',
#       'localTime': '18:30:00',
#       'dateTime': '2023-03-11T23:30:00Z',
#       'dateTBD': False,
#       'dateTBA': False,
#       'timeTBA': False,
#       'noSpecificTime': False},
#      'timezone': 'America/New_York',
#      'status': {'code': 'onsale'},
#      'spanMultipleDays': False},
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAv6', 'name': 'Country'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vAFa', 'name': 'Country'},
#       'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#       'family': False}],
#     'promoter': {'id': '653',
#      'name': 'LIVE NATION MUSIC',
#      'description': 'LIVE NATION MUSIC / NTL / USA'},
#     'promoters': [{'id': '653',
#       'name': 'LIVE NATION MUSIC',
#       'description': 'LIVE NATION MUSIC / NTL / USA'}],
#     'priceRanges': [{'type': 'standard',
#       'currency': 'USD',
#       'min': 65.0,
#       'max': 250.0}],
#     'products': [{'name': 'Parking Pass - Reba McEntire',
#       'id': 'vvG17Z9fG7IA6M',
#       'url': 'https://www.ticketmaster.com/parking-pass-reba-mcentire-charlottesville-virginia-03-11-2023/event/01005D4304A051F7',
#       'type': 'Parking',
#       'classifications': [{'primary': True,
#         'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#         'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#         'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#         'type': {'id': 'KZAyXgnZfZ7vAva', 'name': 'Parking'},
#         'subType': {'id': 'KZFzBErXgnZfZ7vAFe', 'name': 'Parking'},
#         'family': False}]}],
#     'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D3ED3D29CA6/staticImage?type=png&systemId=HOST'},
#     'accessibility': {'ticketLimit': 4},
#     'ticketLimit': {'info': 'There is an overall 8 ticket limit for this event.'},
#     'ageRestrictions': {'legalAgeEnforced': False},
#     'ticketing': {'safeTix': {'enabled': True}},
#     '_links': {'self': {'href': '/discovery/v2/events/vvG17Z9KDKVtwJ?locale=en-us'},
#      'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171a2f?locale=en-us'},
#       {'href': '/discovery/v2/attractions/K8vZ9171fjV?locale=en-us'},
#       {'href': '/discovery/v2/attractions/K8vZ9178Oz7?locale=en-us'}],
#      'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#     '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#        'type': 'venue',
#        'id': 'KovZpZAF6IAA',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#        'locale': 'en-us',
#        'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False}],
#        'postalCode': '22903',
#        'timezone': 'America/New_York',
#        'city': {'name': 'Charlottesville'},
#        'state': {'name': 'Virginia', 'stateCode': 'VA'},
#        'country': {'name': 'United States Of America', 'countryCode': 'US'},
#        'address': {'line1': '295 Massie Rd.'},
#        'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#        'markets': [{'name': 'Virginia', 'id': '46'}],
#        'dmas': [{'id': 246},
#         {'id': 295},
#         {'id': 346},
#         {'id': 369},
#         {'id': 370},
#         {'id': 401}],
#        'social': {'twitter': {'handle': '@JPJArena'}},
#        'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#         'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#         'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#         'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#        'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#        'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#        'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#         'childRule': 'Children less than 1 year of age are free'},
#        'upcomingEvents': {'_total': 46,
#         'tmr': 35,
#         'ticketmaster': 11,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#      'attractions': [{'name': 'Reba McEntire',
#        'type': 'attraction',
#        'id': 'K8vZ9171a2f',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/reba-mcentire-tickets/artist/732860',
#        'locale': 'en-us',
#        'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/user/RebaMcEntireVEVO'}],
#         'twitter': [{'url': 'https://twitter.com/reba'}],
#         'itunes': [{'url': 'https://music.apple.com/us/artist/reba-mcentire/48529'}],
#         'lastfm': [{'url': 'https://www.last.fm/music/Reba+McEntire'}],
#         'wiki': [{'url': 'https://en.wikipedia.org/wiki/Reba_McEntire'}],
#         'facebook': [{'url': 'https://www.facebook.com/reba'}],
#         'spotify': [{'url': 'https://open.spotify.com/artist/02rd0anEWfMtF7iMku9uor'}],
#         'musicbrainz': [{'id': '3ec17e85-9284-4f4c-8831-4e56c2354cdb'}],
#         'instagram': [{'url': 'https://www.instagram.com/reba/'}],
#         'homepage': [{'url': 'http://reba.com/'}]},
#        'aliases': ['reba mcintire', 'reba mcentire', 'reba mcintyre', 'reba'],
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAv6', 'name': 'Country'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7vAFa', 'name': 'Country'},
#          'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#          'family': False}],
#        'upcomingEvents': {'_total': 25,
#         'tmr': 2,
#         'ticketmaster': 23,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171a2f?locale=en-us'}}},
#       {'name': 'Terri Clark',
#        'type': 'attraction',
#        'id': 'K8vZ9171fjV',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/terri-clark-tickets/artist/768026',
#        'locale': 'en-us',
#        'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/user/OfficialTerriClark'}],
#         'twitter': [{'url': 'https://twitter.com/TerriClarkMusic'}],
#         'itunes': [{'url': 'https://open.spotify.com/artist/0HLOP0AdsaWe5Pt5TNueGC'}],
#         'facebook': [{'url': 'http://www.facebook.com/TerriClark'}],
#         'wiki': [{'url': 'https://en.wikipedia.org/wiki/Terri_Clark'}],
#         'spotify': [{'url': 'https://open.spotify.com/artist/0HLOP0AdsaWe5Pt5TNueGC'}],
#         'musicbrainz': [{'id': '58597daa-83ea-4eec-af60-f8437dfdf0e6'}],
#         'instagram': [{'url': 'https://www.instagram.com/terriclarkmusic/'}],
#         'homepage': [{'url': 'http://www.terriclark.com/'}]},
#        'images': [{'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAv6', 'name': 'Country'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7vAFa', 'name': 'Country'},
#          'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#          'family': False}],
#        'upcomingEvents': {'_total': 24,
#         'tmr': 1,
#         'ticketmaster': 23,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171fjV?locale=en-us'}}},
#       {'name': 'The Isaacs',
#        'type': 'attraction',
#        'id': 'K8vZ9178Oz7',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/the-isaacs-tickets/artist/1800794',
#        'locale': 'en-us',
#        'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/channel/UCIhGYisupfP2mv12t7f_gnQ'}],
#         'twitter': [{'url': 'https://twitter.com/IsaacsMusic'}],
#         'itunes': [{'url': 'https://music.apple.com/us/artist/the-isaacs/6599995'}],
#         'wiki': [{'url': 'https://en.wikipedia.org/wiki/The_Isaacs'}],
#         'facebook': [{'url': 'https://www.facebook.com/TheIsaacs/'}],
#         'spotify': [{'url': 'https://open.spotify.com/artist/7Gr7Uulfyw9J9F74eQfBOp?autoplay=true'}],
#         'musicbrainz': [{'id': 'c18472c5-67ce-4d38-9fa3-d5bc2ef856e8'}],
#         'instagram': [{'url': 'https://www.instagram.com/theisaacsmusicofficial/'}],
#         'homepage': [{'url': 'https://www.theisaacs.com/'}]},
#        'images': [{'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAe7', 'name': 'Religious'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7v6ea', 'name': 'Gospel'},
#          'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#          'family': False}],
#        'upcomingEvents': {'_total': 15,
#         'tmr': 2,
#         'ticketmaster': 13,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9178Oz7?locale=en-us'}}}]}},
#    {'name': 'Trans-Siberian Orchestra - The Ghosts Of Christmas Eve',
#     'type': 'event',
#     'id': 'vvG17Z93kRyd7Y',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/transsiberian-orchestra-the-ghosts-of-christmas-charlottesville-virginia-12-15-2022/event/01005D21AFE43130',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False,
#       'attribution': 'Brita Christensen'},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False,
#       'attribution': 'Brita Christensen'}],
#     'sales': {'public': {'startDateTime': '2022-09-16T14:00:00Z',
#       'startTBD': False,
#       'startTBA': False,
#       'endDateTime': '2022-12-16T02:00:00Z'},
#      'presales': [{'startDateTime': '2022-09-16T14:00:00Z',
#        'endDateTime': '2022-11-18T03:00:00Z',
#        'name': 'Citi® Cardmember Preferred Tickets'},
#       {'startDateTime': '2022-09-15T14:00:00Z',
#        'endDateTime': '2022-09-16T03:59:00Z',
#        'name': 'Citi® Cardmember Presale'},
#       {'startDateTime': '2022-09-15T14:00:00Z',
#        'endDateTime': '2022-09-16T03:59:00Z',
#        'name': 'Presales'}]},
#     'dates': {'start': {'localDate': '2022-12-15',
#       'localTime': '19:00:00',
#       'dateTime': '2022-12-16T00:00:00Z',
#       'dateTBD': False,
#       'dateTBA': False,
#       'timeTBA': False,
#       'noSpecificTime': False},
#      'timezone': 'America/New_York',
#      'status': {'code': 'onsale'},
#      'spanMultipleDays': False},
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#       'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#       'family': False}],
#     'promoter': {'id': '653',
#      'name': 'LIVE NATION MUSIC',
#      'description': 'LIVE NATION MUSIC / NTL / USA'},
#     'promoters': [{'id': '653',
#       'name': 'LIVE NATION MUSIC',
#       'description': 'LIVE NATION MUSIC / NTL / USA'}],
#     'priceRanges': [{'type': 'standard',
#       'currency': 'USD',
#       'min': 26.99,
#       'max': 99.5}],
#     'products': [{'name': 'Parking Pass - Trans-Siberian Orchestra',
#       'id': 'vvG17Z93xFSst2',
#       'url': 'https://www.ticketmaster.com/parking-pass-transsiberian-orchestra-charlottesville-virginia-12-15-2022/event/01005D2888CF1A4F',
#       'type': 'Parking',
#       'classifications': [{'primary': True,
#         'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#         'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#         'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#         'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#         'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#         'family': False}]},
#      {'name': 'TSO TIGER LONGSLEEVE T-SHIRT',
#       'id': 'vvG17Z9KRpYfR5',
#       'url': 'https://www.ticketmaster.com/tso-tiger-longsleeve-tshirt-charlottesville-virginia-12-15-2022/event/01005D3BD6C14BCB',
#       'type': 'Upsell',
#       'classifications': [{'primary': True,
#         'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#         'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#         'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#         'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#         'subType': {'id': 'KZFzBErXgnZfZ7vAkd', 'name': 'CD'},
#         'family': False}]}],
#     'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D21AFE43130/staticImage?type=png&systemId=HOST'},
#     'accessibility': {'ticketLimit': 4},
#     'ticketLimit': {'info': 'There is an eight (8) ticket limit on this event. There is a fourteen (14) ticket limit starting on September 23rd.'},
#     'ageRestrictions': {'legalAgeEnforced': False},
#     'ticketing': {'safeTix': {'enabled': True}},
#     '_links': {'self': {'href': '/discovery/v2/events/vvG17Z93kRyd7Y?locale=en-us'},
#      'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171L10?locale=en-us'}],
#      'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#     '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#        'type': 'venue',
#        'id': 'KovZpZAF6IAA',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#        'locale': 'en-us',
#        'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False}],
#        'postalCode': '22903',
#        'timezone': 'America/New_York',
#        'city': {'name': 'Charlottesville'},
#        'state': {'name': 'Virginia', 'stateCode': 'VA'},
#        'country': {'name': 'United States Of America', 'countryCode': 'US'},
#        'address': {'line1': '295 Massie Rd.'},
#        'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#        'markets': [{'name': 'Virginia', 'id': '46'}],
#        'dmas': [{'id': 246},
#         {'id': 295},
#         {'id': 346},
#         {'id': 369},
#         {'id': 370},
#         {'id': 401}],
#        'social': {'twitter': {'handle': '@JPJArena'}},
#        'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#         'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#         'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#         'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#        'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#        'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#        'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#         'childRule': 'Children less than 1 year of age are free'},
#        'upcomingEvents': {'_total': 46,
#         'tmr': 35,
#         'ticketmaster': 11,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#      'attractions': [{'name': 'Trans-Siberian Orchestra',
#        'type': 'attraction',
#        'id': 'K8vZ9171L10',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/transsiberian-orchestra-tickets/artist/780815',
#        'locale': 'en-us',
#        'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/channel/UCH0B_DiwmtVvsYGWdPhmgrQ'}],
#         'twitter': [{'url': 'https://twitter.com/trans_siberian'}],
#         'itunes': [{'url': 'https://itunes.apple.com/us/artist/id165340'}],
#         'lastfm': [{'url': 'http://www.last.fm/music/Trans-Siberian+Orchestra'}],
#         'facebook': [{'url': 'https://www.facebook.com/TSO'}],
#         'spotify': [{'url': 'https://open.spotify.com/artist/5OSQDUNmll299ldFIF1Dau'}],
#         'instagram': [{'url': 'https://www.instagram.com/transsiberianorchestra/'}],
#         'musicbrainz': [{'id': 'd2b83114-af3e-4397-b570-10d81f1dd650'}],
#         'homepage': [{'url': 'http://www.trans-siberian.com/'}]},
#        'aliases': ['TSO'],
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False,
#          'attribution': 'Brita Christensen'},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False,
#          'attribution': 'Brita Christensen'}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#          'type': {'id': 'KZAyXgnZfZ7v7l1', 'name': 'Group'},
#          'subType': {'id': 'KZFzBErXgnZfZ7vA71', 'name': 'Band'},
#          'family': False}],
#        'upcomingEvents': {'_total': 115,
#         'tmr': 16,
#         'ticketmaster': 99,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171L10?locale=en-us'}}}]}},
#    {'name': 'MercyMe X Chris Tomlin',
#     'type': 'event',
#     'id': 'vvG17Z9KMmO4z2',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/mercyme-x-chris-tomlin-charlottesville-virginia-12-02-2022/event/01005D3DEE815E0F',
#     'locale': 'en-us',
#     'images': [{'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False}],
#     'sales': {'public': {'startDateTime': '2022-10-07T14:00:00Z',
#       'startTBD': False,
#       'startTBA': False,
#       'endDateTime': '2022-12-03T02:00:00Z'},
#      'presales': [{'startDateTime': '2022-10-06T14:00:00Z',
#        'endDateTime': '2022-10-07T03:59:00Z',
#        'name': 'Venue Presale'},
#       {'startDateTime': '2022-10-06T14:00:00Z',
#        'endDateTime': '2022-10-07T03:59:00Z',
#        'name': 'Spotify Presale'},
#       {'startDateTime': '2022-10-06T14:00:00Z',
#        'endDateTime': '2022-10-07T03:59:00Z',
#        'name': 'Ticketmaster Presale'},
#       {'startDateTime': '2022-10-05T14:00:00Z',
#        'endDateTime': '2022-10-07T03:59:00Z',
#        'name': 'Sign Up Presale'},
#       {'startDateTime': '2022-10-05T14:00:00Z',
#        'endDateTime': '2022-10-07T03:59:00Z',
#        'name': 'Official Platinum Presale'},
#       {'startDateTime': '2022-10-07T14:00:00Z',
#        'endDateTime': '2022-12-03T02:00:00Z',
#        'name': 'Official Platinum'},
#       {'startDateTime': '2022-10-06T14:00:00Z',
#        'endDateTime': '2022-10-07T03:59:00Z',
#        'name': 'Venue Pre-Sale'}]},
#     'dates': {'start': {'localDate': '2022-12-02',
#       'localTime': '19:00:00',
#       'dateTime': '2022-12-03T00:00:00Z',
#       'dateTBD': False,
#       'dateTBA': False,
#       'timeTBA': False,
#       'noSpecificTime': False},
#      'timezone': 'America/New_York',
#      'status': {'code': 'onsale'},
#      'spanMultipleDays': False},
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#       'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#       'family': False}],
#     'priceRanges': [{'type': 'standard',
#       'currency': 'USD',
#       'min': 0.01,
#       'max': 160.0}],
#     'products': [{'name': 'Parking Pass - Chris Tomlin X MercyMe',
#       'id': 'vvG17Z9fGAYg1j',
#       'url': 'https://www.ticketmaster.com/parking-pass-chris-tomlin-x-mercyme-charlottesville-virginia-12-02-2022/event/01005D4305C3529C',
#       'type': 'Parking',
#       'classifications': [{'primary': True,
#         'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#         'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#         'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#         'type': {'id': 'KZAyXgnZfZ7vAva', 'name': 'Parking'},
#         'subType': {'id': 'KZFzBErXgnZfZ7vAFe', 'name': 'Parking'},
#         'family': False}]}],
#     'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D3DEE815E0F/staticImage?type=png&systemId=HOST'},
#     'accessibility': {'ticketLimit': 4},
#     'ageRestrictions': {'legalAgeEnforced': False},
#     'ticketing': {'safeTix': {'enabled': True}},
#     '_links': {'self': {'href': '/discovery/v2/events/vvG17Z9KMmO4z2?locale=en-us'},
#      'attractions': [{'href': '/discovery/v2/attractions/K8vZ9175_R0?locale=en-us'},
#       {'href': '/discovery/v2/attractions/K8vZ9175WR0?locale=en-us'}],
#      'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#     '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#        'type': 'venue',
#        'id': 'KovZpZAF6IAA',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#        'locale': 'en-us',
#        'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False}],
#        'postalCode': '22903',
#        'timezone': 'America/New_York',
#        'city': {'name': 'Charlottesville'},
#        'state': {'name': 'Virginia', 'stateCode': 'VA'},
#        'country': {'name': 'United States Of America', 'countryCode': 'US'},
#        'address': {'line1': '295 Massie Rd.'},
#        'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#        'markets': [{'name': 'Virginia', 'id': '46'}],
#        'dmas': [{'id': 246},
#         {'id': 295},
#         {'id': 346},
#         {'id': 369},
#         {'id': 370},
#         {'id': 401}],
#        'social': {'twitter': {'handle': '@JPJArena'}},
#        'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#         'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#         'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#         'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#        'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#        'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#        'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#         'childRule': 'Children less than 1 year of age are free'},
#        'upcomingEvents': {'_total': 46,
#         'tmr': 35,
#         'ticketmaster': 11,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#      'attractions': [{'name': 'MercyMe',
#        'type': 'attraction',
#        'id': 'K8vZ9175_R0',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/mercyme-tickets/artist/873854',
#        'locale': 'en-us',
#        'externalLinks': {'wiki': [{'url': 'https://en.wikipedia.org/wiki/MercyMe'}],
#         'musicbrainz': [{'id': 'c5a016d4-567e-4698-96a2-af134adb8395'}],
#         'homepage': [{'url': 'http://mercyme.org/'}]},
#        'images': [{'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
# ...
#         'childRule': 'Children less than 1 year of age are free'},
#        'upcomingEvents': {'_total': 46,
#         'tmr': 35,
#         'ticketmaster': 11,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#      'attractions': [{'name': 'Hot Wheels Crash Zone Pre-Party',
#        'type': 'attraction',
#        'id': 'K8vZ917_sZ0',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/hot-wheels-crash-zone-preparty-tickets/artist/2800762',
#        'locale': 'en-us',
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#          'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#          'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lv', 'name': 'Special Entry'},
#          'family': False}],
#        'upcomingEvents': {'_total': 7, 'ticketmaster': 7, '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917_sZ0?locale=en-us'}}}]}},
#    {'name': 'Hot Wheels Crash Zone Pre-Party From 10:00am-11:15am',
#     'type': 'event',
#     'id': 'vvG17Z9o66xNys',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/hot-wheels-crash-zone-preparty-from-charlottesville-virginia-03-25-2023/event/01005D11C78A3E71',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False}],
#     'sales': {'public': {'startDateTime': '2022-09-08T14:00:00Z',
#       'startTBD': False,
#       'startTBA': False,
#       'endDateTime': '2023-03-25T16:00:00Z'}},
#     'dates': {'start': {'localDate': '2023-03-25',
#       'localTime': '12:30:00',
#       'dateTime': '2023-03-25T16:30:00Z',
#       'dateTBD': False,
#       'dateTBA': False,
#       'timeTBA': False,
#       'noSpecificTime': False},
#      'timezone': 'America/New_York',
#      'status': {'code': 'onsale'},
#      'spanMultipleDays': False},
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#       'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#       'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lv', 'name': 'Special Entry'},
#       'family': False}],
#     'pleaseNote': 'The Hot Wheels Crash Zone Pre-Show Party is an event that gives fans exclusive access to their favorite Hot Wheels Monster Trucks up close! This unique experience allows fans to enter the competition floor before the show and get their minds blown by the outrageous design and epic size of the Hot Wheels Monster Trucks. Experience the heart of where all the epic crashes and thrilling stunts will take place. This party also features exclusive games, contests and giveaways. If you want to go big, you gotta go Hot Wheels at the Crash Zone Pre-Show Party!',
#     'priceRanges': [{'type': 'standard',
#       'currency': 'USD',
#       'min': 7.5,
#       'max': 7.5}],
#     'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D11C78A3E71/staticImage?type=png&systemId=HOST'},
#     'accessibility': {'ticketLimit': 4},
#     'ageRestrictions': {'legalAgeEnforced': False},
#     'ticketing': {'safeTix': {'enabled': True}},
#     '_links': {'self': {'href': '/discovery/v2/events/vvG17Z9o66xNys?locale=en-us'},
#      'attractions': [{'href': '/discovery/v2/attractions/K8vZ917_sZ0?locale=en-us'}],
#      'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#     '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#        'type': 'venue',
#        'id': 'KovZpZAF6IAA',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#        'locale': 'en-us',
#        'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False}],
#        'postalCode': '22903',
#        'timezone': 'America/New_York',
#        'city': {'name': 'Charlottesville'},
#        'state': {'name': 'Virginia', 'stateCode': 'VA'},
#        'country': {'name': 'United States Of America', 'countryCode': 'US'},
#        'address': {'line1': '295 Massie Rd.'},
#        'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#        'markets': [{'name': 'Virginia', 'id': '46'}],
#        'dmas': [{'id': 246},
#         {'id': 295},
#         {'id': 346},
#         {'id': 369},
#         {'id': 370},
#         {'id': 401}],
#        'social': {'twitter': {'handle': '@JPJArena'}},
#        'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#         'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#         'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#         'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#        'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#        'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#        'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#         'childRule': 'Children less than 1 year of age are free'},
#        'upcomingEvents': {'_total': 46,
#         'tmr': 35,
#         'ticketmaster': 11,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#      'attractions': [{'name': 'Hot Wheels Crash Zone Pre-Party',
#        'type': 'attraction',
#        'id': 'K8vZ917_sZ0',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/hot-wheels-crash-zone-preparty-tickets/artist/2800762',
#        'locale': 'en-us',
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#          'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#          'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lv', 'name': 'Special Entry'},
#          'family': False}],
#        'upcomingEvents': {'_total': 7, 'ticketmaster': 7, '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917_sZ0?locale=en-us'}}}]}}]},
#  '_links': {'self': {'href': '/discovery/v2/events.json?postalCode=22903'}},
#  'page': {'size': 20, 'totalElements': 14, 'totalPages': 1, 'number': 0}}

# %%
# Displaying the events occuring at the inputed zipcode (Directions: Click "Run" to build the "events" variable which contains all the events on Ticket Master occuring at that zipcode)
events = data['_embedded']['events']
events
# Out:
# [{'name': 'Reba McEntire',
#   'type': 'event',
#   'id': 'vvG17Z9KDKVtwJ',
#   'test': False,
#   'url': 'https://www.ticketmaster.com/reba-mcentire-charlottesville-virginia-03-11-2023/event/01005D3ED3D29CA6',
#   'locale': 'en-us',
#   'images': [{'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_LANDSCAPE_16_9.jpg',
#     'width': 1136,
#     'height': 639,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_16_9.jpg',
#     'width': 1024,
#     'height': 576,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_EVENT_DETAIL_PAGE_16_9.jpg',
#     'width': 205,
#     'height': 115,
#     'fallback': False},
#    {'ratio': '4_3',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_CUSTOM.jpg',
#     'width': 305,
#     'height': 225,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_3_2.jpg',
#     'width': 640,
#     'height': 427,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RECOMENDATION_16_9.jpg',
#     'width': 100,
#     'height': 56,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_3_2.jpg',
#     'width': 1024,
#     'height': 683,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_ARTIST_PAGE_3_2.jpg',
#     'width': 305,
#     'height': 203,
#     'fallback': False}],
#   'sales': {'public': {'startDateTime': '2022-10-07T14:00:00Z',
#     'startTBD': False,
#     'startTBA': False,
#     'endDateTime': '2023-03-12T00:30:00Z'},
#    'presales': [{'startDateTime': '2022-10-04T14:00:00Z',
#      'endDateTime': '2022-10-07T02:00:00Z',
#      'name': 'VIP Packages Presale'},
#     {'startDateTime': '2022-10-04T14:00:00Z',
#      'endDateTime': '2022-10-07T02:00:00Z',
#      'name': 'Reba McEntire Artist Presale'},
#     {'startDateTime': '2022-10-05T14:00:00Z',
#      'endDateTime': '2022-10-07T02:00:00Z',
#      'name': 'Terri Clark Artist Presale'},
#     {'startDateTime': '2022-10-07T14:00:00Z',
#      'endDateTime': '2023-03-02T03:00:00Z',
#      'name': 'VIP Packages Onsale'},
#     {'startDateTime': '2022-10-04T14:00:00Z',
#      'endDateTime': '2022-10-07T02:00:00Z',
#      'name': 'Official Platinum Presale'},
#     {'startDateTime': '2022-10-07T14:00:00Z',
#      'endDateTime': '2023-03-12T01:00:00Z',
#      'name': 'Official Platinum'},
#     {'startDateTime': '2022-10-04T14:00:00Z',
#      'endDateTime': '2022-10-07T02:00:00Z',
#      'name': 'Citi® Cardmember Presale'},
#     {'startDateTime': '2022-10-07T14:00:00Z',
#      'endDateTime': '2023-02-19T03:00:00Z',
#      'name': 'Citi® Cardmember Preferred Tickets'},
#     {'startDateTime': '2022-10-06T14:00:00Z',
#      'endDateTime': '2022-10-07T02:00:00Z',
#      'name': 'Live Nation Presale'},
#     {'startDateTime': '2022-10-06T14:00:00Z',
#      'endDateTime': '2022-10-07T02:00:00Z',
#      'name': 'RADIO/VENUE/LOCAL PRESALE'},
#     {'startDateTime': '2022-10-04T14:00:00Z',
#      'endDateTime': '2023-03-12T00:30:00Z',
#      'name': 'Lower Level Preferred Seating'},
#     {'startDateTime': '2022-10-04T14:00:00Z',
#      'endDateTime': '2023-03-12T00:30:00Z',
#      'name': 'Upper Level Preferred Seating'}]},
#   'dates': {'start': {'localDate': '2023-03-11',
#     'localTime': '18:30:00',
#     'dateTime': '2023-03-11T23:30:00Z',
#     'dateTBD': False,
#     'dateTBA': False,
#     'timeTBA': False,
#     'noSpecificTime': False},
#    'timezone': 'America/New_York',
#    'status': {'code': 'onsale'},
#    'spanMultipleDays': False},
#   'classifications': [{'primary': True,
#     'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#     'genre': {'id': 'KnvZfZ7vAv6', 'name': 'Country'},
#     'subGenre': {'id': 'KZazBEonSMnZfZ7vAFa', 'name': 'Country'},
#     'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#     'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#     'family': False}],
#   'promoter': {'id': '653',
#    'name': 'LIVE NATION MUSIC',
#    'description': 'LIVE NATION MUSIC / NTL / USA'},
#   'promoters': [{'id': '653',
#     'name': 'LIVE NATION MUSIC',
#     'description': 'LIVE NATION MUSIC / NTL / USA'}],
#   'priceRanges': [{'type': 'standard',
#     'currency': 'USD',
#     'min': 65.0,
#     'max': 250.0}],
#   'products': [{'name': 'Parking Pass - Reba McEntire',
#     'id': 'vvG17Z9fG7IA6M',
#     'url': 'https://www.ticketmaster.com/parking-pass-reba-mcentire-charlottesville-virginia-03-11-2023/event/01005D4304A051F7',
#     'type': 'Parking',
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#       'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#       'type': {'id': 'KZAyXgnZfZ7vAva', 'name': 'Parking'},
#       'subType': {'id': 'KZFzBErXgnZfZ7vAFe', 'name': 'Parking'},
#       'family': False}]}],
#   'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D3ED3D29CA6/staticImage?type=png&systemId=HOST'},
#   'accessibility': {'ticketLimit': 4},
#   'ticketLimit': {'info': 'There is an overall 8 ticket limit for this event.'},
#   'ageRestrictions': {'legalAgeEnforced': False},
#   'ticketing': {'safeTix': {'enabled': True}},
#   '_links': {'self': {'href': '/discovery/v2/events/vvG17Z9KDKVtwJ?locale=en-us'},
#    'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171a2f?locale=en-us'},
#     {'href': '/discovery/v2/attractions/K8vZ9171fjV?locale=en-us'},
#     {'href': '/discovery/v2/attractions/K8vZ9178Oz7?locale=en-us'}],
#    'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#   '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#      'type': 'venue',
#      'id': 'KovZpZAF6IAA',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#      'locale': 'en-us',
#      'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False}],
#      'postalCode': '22903',
#      'timezone': 'America/New_York',
#      'city': {'name': 'Charlottesville'},
#      'state': {'name': 'Virginia', 'stateCode': 'VA'},
#      'country': {'name': 'United States Of America', 'countryCode': 'US'},
#      'address': {'line1': '295 Massie Rd.'},
#      'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#      'markets': [{'name': 'Virginia', 'id': '46'}],
#      'dmas': [{'id': 246},
#       {'id': 295},
#       {'id': 346},
#       {'id': 369},
#       {'id': 370},
#       {'id': 401}],
#      'social': {'twitter': {'handle': '@JPJArena'}},
#      'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#       'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#       'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#       'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#      'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#      'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#      'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#       'childRule': 'Children less than 1 year of age are free'},
#      'upcomingEvents': {'_total': 46,
#       'tmr': 35,
#       'ticketmaster': 11,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#    'attractions': [{'name': 'Reba McEntire',
#      'type': 'attraction',
#      'id': 'K8vZ9171a2f',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/reba-mcentire-tickets/artist/732860',
#      'locale': 'en-us',
#      'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/user/RebaMcEntireVEVO'}],
#       'twitter': [{'url': 'https://twitter.com/reba'}],
#       'itunes': [{'url': 'https://music.apple.com/us/artist/reba-mcentire/48529'}],
#       'lastfm': [{'url': 'https://www.last.fm/music/Reba+McEntire'}],
#       'wiki': [{'url': 'https://en.wikipedia.org/wiki/Reba_McEntire'}],
#       'facebook': [{'url': 'https://www.facebook.com/reba'}],
#       'spotify': [{'url': 'https://open.spotify.com/artist/02rd0anEWfMtF7iMku9uor'}],
#       'musicbrainz': [{'id': '3ec17e85-9284-4f4c-8831-4e56c2354cdb'}],
#       'instagram': [{'url': 'https://www.instagram.com/reba/'}],
#       'homepage': [{'url': 'http://reba.com/'}]},
#      'aliases': ['reba mcintire', 'reba mcentire', 'reba mcintyre', 'reba'],
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False},
#       {'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/221/403aa60d-ed01-4220-a679-91a4dd8f8221_1204351_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#        'genre': {'id': 'KnvZfZ7vAv6', 'name': 'Country'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7vAFa', 'name': 'Country'},
#        'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#        'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#        'family': False}],
#      'upcomingEvents': {'_total': 25,
#       'tmr': 2,
#       'ticketmaster': 23,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171a2f?locale=en-us'}}},
#     {'name': 'Terri Clark',
#      'type': 'attraction',
#      'id': 'K8vZ9171fjV',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/terri-clark-tickets/artist/768026',
#      'locale': 'en-us',
#      'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/user/OfficialTerriClark'}],
#       'twitter': [{'url': 'https://twitter.com/TerriClarkMusic'}],
#       'itunes': [{'url': 'https://open.spotify.com/artist/0HLOP0AdsaWe5Pt5TNueGC'}],
#       'facebook': [{'url': 'http://www.facebook.com/TerriClark'}],
#       'wiki': [{'url': 'https://en.wikipedia.org/wiki/Terri_Clark'}],
#       'spotify': [{'url': 'https://open.spotify.com/artist/0HLOP0AdsaWe5Pt5TNueGC'}],
#       'musicbrainz': [{'id': '58597daa-83ea-4eec-af60-f8437dfdf0e6'}],
#       'instagram': [{'url': 'https://www.instagram.com/terriclarkmusic/'}],
#       'homepage': [{'url': 'http://www.terriclark.com/'}]},
#      'images': [{'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/8f4/246aa275-b14f-421c-a9b5-e48d101138f4_1736931_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#        'genre': {'id': 'KnvZfZ7vAv6', 'name': 'Country'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7vAFa', 'name': 'Country'},
#        'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#        'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#        'family': False}],
#      'upcomingEvents': {'_total': 24,
#       'tmr': 1,
#       'ticketmaster': 23,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171fjV?locale=en-us'}}},
#     {'name': 'The Isaacs',
#      'type': 'attraction',
#      'id': 'K8vZ9178Oz7',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/the-isaacs-tickets/artist/1800794',
#      'locale': 'en-us',
#      'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/channel/UCIhGYisupfP2mv12t7f_gnQ'}],
#       'twitter': [{'url': 'https://twitter.com/IsaacsMusic'}],
#       'itunes': [{'url': 'https://music.apple.com/us/artist/the-isaacs/6599995'}],
#       'wiki': [{'url': 'https://en.wikipedia.org/wiki/The_Isaacs'}],
#       'facebook': [{'url': 'https://www.facebook.com/TheIsaacs/'}],
#       'spotify': [{'url': 'https://open.spotify.com/artist/7Gr7Uulfyw9J9F74eQfBOp?autoplay=true'}],
#       'musicbrainz': [{'id': 'c18472c5-67ce-4d38-9fa3-d5bc2ef856e8'}],
#       'instagram': [{'url': 'https://www.instagram.com/theisaacsmusicofficial/'}],
#       'homepage': [{'url': 'https://www.theisaacs.com/'}]},
#      'images': [{'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False},
#       {'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/524/8e11b56c-3520-48d1-aba6-4184c5cd2524_1474201_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#        'genre': {'id': 'KnvZfZ7vAe7', 'name': 'Religious'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7v6ea', 'name': 'Gospel'},
#        'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#        'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#        'family': False}],
#      'upcomingEvents': {'_total': 15,
#       'tmr': 2,
#       'ticketmaster': 13,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9178Oz7?locale=en-us'}}}]}},
#  {'name': 'Trans-Siberian Orchestra - The Ghosts Of Christmas Eve',
#   'type': 'event',
#   'id': 'vvG17Z93kRyd7Y',
#   'test': False,
#   'url': 'https://www.ticketmaster.com/transsiberian-orchestra-the-ghosts-of-christmas-charlottesville-virginia-12-15-2022/event/01005D21AFE43130',
#   'locale': 'en-us',
#   'images': [{'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_16_9.jpg',
#     'width': 1024,
#     'height': 576,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_LANDSCAPE_16_9.jpg',
#     'width': 1136,
#     'height': 639,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_EVENT_DETAIL_PAGE_16_9.jpg',
#     'width': 205,
#     'height': 115,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_3_2.jpg',
#     'width': 640,
#     'height': 427,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_3_2.jpg',
#     'width': 1024,
#     'height': 683,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RECOMENDATION_16_9.jpg',
#     'width': 100,
#     'height': 56,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '4_3',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_CUSTOM.jpg',
#     'width': 305,
#     'height': 225,
#     'fallback': False,
#     'attribution': 'Brita Christensen'},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_ARTIST_PAGE_3_2.jpg',
#     'width': 305,
#     'height': 203,
#     'fallback': False,
#     'attribution': 'Brita Christensen'}],
#   'sales': {'public': {'startDateTime': '2022-09-16T14:00:00Z',
#     'startTBD': False,
#     'startTBA': False,
#     'endDateTime': '2022-12-16T02:00:00Z'},
#    'presales': [{'startDateTime': '2022-09-16T14:00:00Z',
#      'endDateTime': '2022-11-18T03:00:00Z',
#      'name': 'Citi® Cardmember Preferred Tickets'},
#     {'startDateTime': '2022-09-15T14:00:00Z',
#      'endDateTime': '2022-09-16T03:59:00Z',
#      'name': 'Citi® Cardmember Presale'},
#     {'startDateTime': '2022-09-15T14:00:00Z',
#      'endDateTime': '2022-09-16T03:59:00Z',
#      'name': 'Presales'}]},
#   'dates': {'start': {'localDate': '2022-12-15',
#     'localTime': '19:00:00',
#     'dateTime': '2022-12-16T00:00:00Z',
#     'dateTBD': False,
#     'dateTBA': False,
#     'timeTBA': False,
#     'noSpecificTime': False},
#    'timezone': 'America/New_York',
#    'status': {'code': 'onsale'},
#    'spanMultipleDays': False},
#   'classifications': [{'primary': True,
#     'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#     'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#     'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#     'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#     'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#     'family': False}],
#   'promoter': {'id': '653',
#    'name': 'LIVE NATION MUSIC',
#    'description': 'LIVE NATION MUSIC / NTL / USA'},
#   'promoters': [{'id': '653',
#     'name': 'LIVE NATION MUSIC',
#     'description': 'LIVE NATION MUSIC / NTL / USA'}],
#   'priceRanges': [{'type': 'standard',
#     'currency': 'USD',
#     'min': 26.99,
#     'max': 99.5}],
#   'products': [{'name': 'Parking Pass - Trans-Siberian Orchestra',
#     'id': 'vvG17Z93xFSst2',
#     'url': 'https://www.ticketmaster.com/parking-pass-transsiberian-orchestra-charlottesville-virginia-12-15-2022/event/01005D2888CF1A4F',
#     'type': 'Parking',
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#       'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#       'family': False}]},
#    {'name': 'TSO TIGER LONGSLEEVE T-SHIRT',
#     'id': 'vvG17Z9KRpYfR5',
#     'url': 'https://www.ticketmaster.com/tso-tiger-longsleeve-tshirt-charlottesville-virginia-12-15-2022/event/01005D3BD6C14BCB',
#     'type': 'Upsell',
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#       'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#       'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#       'subType': {'id': 'KZFzBErXgnZfZ7vAkd', 'name': 'CD'},
#       'family': False}]}],
#   'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D21AFE43130/staticImage?type=png&systemId=HOST'},
#   'accessibility': {'ticketLimit': 4},
#   'ticketLimit': {'info': 'There is an eight (8) ticket limit on this event. There is a fourteen (14) ticket limit starting on September 23rd.'},
#   'ageRestrictions': {'legalAgeEnforced': False},
#   'ticketing': {'safeTix': {'enabled': True}},
#   '_links': {'self': {'href': '/discovery/v2/events/vvG17Z93kRyd7Y?locale=en-us'},
#    'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171L10?locale=en-us'}],
#    'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#   '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#      'type': 'venue',
#      'id': 'KovZpZAF6IAA',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#      'locale': 'en-us',
#      'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False}],
#      'postalCode': '22903',
#      'timezone': 'America/New_York',
#      'city': {'name': 'Charlottesville'},
#      'state': {'name': 'Virginia', 'stateCode': 'VA'},
#      'country': {'name': 'United States Of America', 'countryCode': 'US'},
#      'address': {'line1': '295 Massie Rd.'},
#      'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#      'markets': [{'name': 'Virginia', 'id': '46'}],
#      'dmas': [{'id': 246},
#       {'id': 295},
#       {'id': 346},
#       {'id': 369},
#       {'id': 370},
#       {'id': 401}],
#      'social': {'twitter': {'handle': '@JPJArena'}},
#      'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#       'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#       'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#       'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#      'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#      'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#      'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#       'childRule': 'Children less than 1 year of age are free'},
#      'upcomingEvents': {'_total': 46,
#       'tmr': 35,
#       'ticketmaster': 11,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#    'attractions': [{'name': 'Trans-Siberian Orchestra',
#      'type': 'attraction',
#      'id': 'K8vZ9171L10',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/transsiberian-orchestra-tickets/artist/780815',
#      'locale': 'en-us',
#      'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/channel/UCH0B_DiwmtVvsYGWdPhmgrQ'}],
#       'twitter': [{'url': 'https://twitter.com/trans_siberian'}],
#       'itunes': [{'url': 'https://itunes.apple.com/us/artist/id165340'}],
#       'lastfm': [{'url': 'http://www.last.fm/music/Trans-Siberian+Orchestra'}],
#       'facebook': [{'url': 'https://www.facebook.com/TSO'}],
#       'spotify': [{'url': 'https://open.spotify.com/artist/5OSQDUNmll299ldFIF1Dau'}],
#       'instagram': [{'url': 'https://www.instagram.com/transsiberianorchestra/'}],
#       'musicbrainz': [{'id': 'd2b83114-af3e-4397-b570-10d81f1dd650'}],
#       'homepage': [{'url': 'http://www.trans-siberian.com/'}]},
#      'aliases': ['TSO'],
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False,
#        'attribution': 'Brita Christensen'},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/087/d26e3794-731e-478c-b0ba-4b4648bd0087_1772721_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False,
#        'attribution': 'Brita Christensen'}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#        'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#        'type': {'id': 'KZAyXgnZfZ7v7l1', 'name': 'Group'},
#        'subType': {'id': 'KZFzBErXgnZfZ7vA71', 'name': 'Band'},
#        'family': False}],
#      'upcomingEvents': {'_total': 115,
#       'tmr': 16,
#       'ticketmaster': 99,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171L10?locale=en-us'}}}]}},
#  {'name': 'MercyMe X Chris Tomlin',
#   'type': 'event',
#   'id': 'vvG17Z9KMmO4z2',
#   'test': False,
#   'url': 'https://www.ticketmaster.com/mercyme-x-chris-tomlin-charlottesville-virginia-12-02-2022/event/01005D3DEE815E0F',
#   'locale': 'en-us',
#   'images': [{'ratio': '4_3',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_CUSTOM.jpg',
#     'width': 305,
#     'height': 225,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_3_2.jpg',
#     'width': 1024,
#     'height': 683,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_PORTRAIT_3_2.jpg',
#     'width': 640,
#     'height': 427,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RECOMENDATION_16_9.jpg',
#     'width': 100,
#     'height': 56,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_EVENT_DETAIL_PAGE_16_9.jpg',
#     'width': 205,
#     'height': 115,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_16_9.jpg',
#     'width': 1024,
#     'height': 576,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_LANDSCAPE_16_9.jpg',
#     'width': 1136,
#     'height': 639,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_ARTIST_PAGE_3_2.jpg',
#     'width': 305,
#     'height': 203,
#     'fallback': False}],
#   'sales': {'public': {'startDateTime': '2022-10-07T14:00:00Z',
#     'startTBD': False,
#     'startTBA': False,
#     'endDateTime': '2022-12-03T02:00:00Z'},
#    'presales': [{'startDateTime': '2022-10-06T14:00:00Z',
#      'endDateTime': '2022-10-07T03:59:00Z',
#      'name': 'Venue Presale'},
#     {'startDateTime': '2022-10-06T14:00:00Z',
#      'endDateTime': '2022-10-07T03:59:00Z',
#      'name': 'Spotify Presale'},
#     {'startDateTime': '2022-10-06T14:00:00Z',
#      'endDateTime': '2022-10-07T03:59:00Z',
#      'name': 'Ticketmaster Presale'},
#     {'startDateTime': '2022-10-05T14:00:00Z',
#      'endDateTime': '2022-10-07T03:59:00Z',
#      'name': 'Sign Up Presale'},
#     {'startDateTime': '2022-10-05T14:00:00Z',
#      'endDateTime': '2022-10-07T03:59:00Z',
#      'name': 'Official Platinum Presale'},
#     {'startDateTime': '2022-10-07T14:00:00Z',
#      'endDateTime': '2022-12-03T02:00:00Z',
#      'name': 'Official Platinum'},
#     {'startDateTime': '2022-10-06T14:00:00Z',
#      'endDateTime': '2022-10-07T03:59:00Z',
#      'name': 'Venue Pre-Sale'}]},
#   'dates': {'start': {'localDate': '2022-12-02',
#     'localTime': '19:00:00',
#     'dateTime': '2022-12-03T00:00:00Z',
#     'dateTBD': False,
#     'dateTBA': False,
#     'timeTBA': False,
#     'noSpecificTime': False},
#    'timezone': 'America/New_York',
#    'status': {'code': 'onsale'},
#    'spanMultipleDays': False},
#   'classifications': [{'primary': True,
#     'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#     'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#     'subGenre': {'id': 'KZazBEonSMnZfZ7v6F1', 'name': 'Pop'},
#     'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#     'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#     'family': False}],
#   'priceRanges': [{'type': 'standard',
#     'currency': 'USD',
#     'min': 0.01,
#     'max': 160.0}],
#   'products': [{'name': 'Parking Pass - Chris Tomlin X MercyMe',
#     'id': 'vvG17Z9fGAYg1j',
#     'url': 'https://www.ticketmaster.com/parking-pass-chris-tomlin-x-mercyme-charlottesville-virginia-12-02-2022/event/01005D4305C3529C',
#     'type': 'Parking',
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#       'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#       'type': {'id': 'KZAyXgnZfZ7vAva', 'name': 'Parking'},
#       'subType': {'id': 'KZFzBErXgnZfZ7vAFe', 'name': 'Parking'},
#       'family': False}]}],
#   'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D3DEE815E0F/staticImage?type=png&systemId=HOST'},
#   'accessibility': {'ticketLimit': 4},
#   'ageRestrictions': {'legalAgeEnforced': False},
#   'ticketing': {'safeTix': {'enabled': True}},
#   '_links': {'self': {'href': '/discovery/v2/events/vvG17Z9KMmO4z2?locale=en-us'},
#    'attractions': [{'href': '/discovery/v2/attractions/K8vZ9175_R0?locale=en-us'},
#     {'href': '/discovery/v2/attractions/K8vZ9175WR0?locale=en-us'}],
#    'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#   '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#      'type': 'venue',
#      'id': 'KovZpZAF6IAA',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#      'locale': 'en-us',
#      'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False}],
#      'postalCode': '22903',
#      'timezone': 'America/New_York',
#      'city': {'name': 'Charlottesville'},
#      'state': {'name': 'Virginia', 'stateCode': 'VA'},
#      'country': {'name': 'United States Of America', 'countryCode': 'US'},
#      'address': {'line1': '295 Massie Rd.'},
#      'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#      'markets': [{'name': 'Virginia', 'id': '46'}],
#      'dmas': [{'id': 246},
#       {'id': 295},
#       {'id': 346},
#       {'id': 369},
#       {'id': 370},
#       {'id': 401}],
#      'social': {'twitter': {'handle': '@JPJArena'}},
#      'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#       'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#       'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#       'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#      'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#      'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#      'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#       'childRule': 'Children less than 1 year of age are free'},
#      'upcomingEvents': {'_total': 46,
#       'tmr': 35,
#       'ticketmaster': 11,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#    'attractions': [{'name': 'MercyMe',
#      'type': 'attraction',
#      'id': 'K8vZ9175_R0',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/mercyme-tickets/artist/873854',
#      'locale': 'en-us',
#      'externalLinks': {'wiki': [{'url': 'https://en.wikipedia.org/wiki/MercyMe'}],
#       'musicbrainz': [{'id': 'c5a016d4-567e-4698-96a2-af134adb8395'}],
#       'homepage': [{'url': 'http://mercyme.org/'}]},
#      'images': [{'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/85c/d68735d8-20db-4571-b244-d70cf5a3485c_285531_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False}],
# ...
#       'childRule': 'Children less than 1 year of age are free'},
#      'upcomingEvents': {'_total': 46,
#       'tmr': 35,
#       'ticketmaster': 11,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#    'attractions': [{'name': 'Hot Wheels Crash Zone Pre-Party',
#      'type': 'attraction',
#      'id': 'K8vZ917_sZ0',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/hot-wheels-crash-zone-preparty-tickets/artist/2800762',
#      'locale': 'en-us',
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False},
#       {'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#        'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#        'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#        'subType': {'id': 'KZFzBErXgnZfZ7v7lv', 'name': 'Special Entry'},
#        'family': False}],
#      'upcomingEvents': {'_total': 7, 'ticketmaster': 7, '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917_sZ0?locale=en-us'}}}]}},
#  {'name': 'Hot Wheels Crash Zone Pre-Party From 10:00am-11:15am',
#   'type': 'event',
#   'id': 'vvG17Z9o66xNys',
#   'test': False,
#   'url': 'https://www.ticketmaster.com/hot-wheels-crash-zone-preparty-from-charlottesville-virginia-03-25-2023/event/01005D11C78A3E71',
#   'locale': 'en-us',
#   'images': [{'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_LANDSCAPE_16_9.jpg',
#     'width': 1136,
#     'height': 639,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_3_2.jpg',
#     'width': 640,
#     'height': 427,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_3_2.jpg',
#     'width': 1024,
#     'height': 683,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
#     'fallback': False},
#    {'ratio': '4_3',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_CUSTOM.jpg',
#     'width': 305,
#     'height': 225,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RECOMENDATION_16_9.jpg',
#     'width': 100,
#     'height': 56,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_EVENT_DETAIL_PAGE_16_9.jpg',
#     'width': 205,
#     'height': 115,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_16_9.jpg',
#     'width': 1024,
#     'height': 576,
#     'fallback': False},
#    {'ratio': '3_2',
#     'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_ARTIST_PAGE_3_2.jpg',
#     'width': 305,
#     'height': 203,
#     'fallback': False}],
#   'sales': {'public': {'startDateTime': '2022-09-08T14:00:00Z',
#     'startTBD': False,
#     'startTBA': False,
#     'endDateTime': '2023-03-25T16:00:00Z'}},
#   'dates': {'start': {'localDate': '2023-03-25',
#     'localTime': '12:30:00',
#     'dateTime': '2023-03-25T16:30:00Z',
#     'dateTBD': False,
#     'dateTBA': False,
#     'timeTBA': False,
#     'noSpecificTime': False},
#    'timezone': 'America/New_York',
#    'status': {'code': 'onsale'},
#    'spanMultipleDays': False},
#   'classifications': [{'primary': True,
#     'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#     'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#     'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#     'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#     'subType': {'id': 'KZFzBErXgnZfZ7v7lv', 'name': 'Special Entry'},
#     'family': False}],
#   'pleaseNote': 'The Hot Wheels Crash Zone Pre-Show Party is an event that gives fans exclusive access to their favorite Hot Wheels Monster Trucks up close! This unique experience allows fans to enter the competition floor before the show and get their minds blown by the outrageous design and epic size of the Hot Wheels Monster Trucks. Experience the heart of where all the epic crashes and thrilling stunts will take place. This party also features exclusive games, contests and giveaways. If you want to go big, you gotta go Hot Wheels at the Crash Zone Pre-Show Party!',
#   'priceRanges': [{'type': 'standard',
#     'currency': 'USD',
#     'min': 7.5,
#     'max': 7.5}],
#   'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/01005D11C78A3E71/staticImage?type=png&systemId=HOST'},
#   'accessibility': {'ticketLimit': 4},
#   'ageRestrictions': {'legalAgeEnforced': False},
#   'ticketing': {'safeTix': {'enabled': True}},
#   '_links': {'self': {'href': '/discovery/v2/events/vvG17Z9o66xNys?locale=en-us'},
#    'attractions': [{'href': '/discovery/v2/attractions/K8vZ917_sZ0?locale=en-us'}],
#    'venues': [{'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}]},
#   '_embedded': {'venues': [{'name': 'John Paul Jones Arena',
#      'type': 'venue',
#      'id': 'KovZpZAF6IAA',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/john-paul-jones-arena-tickets-charlottesville/venue/8997',
#      'locale': 'en-us',
#      'aliases': ['john paul jones', 'jpj', 'jpj arena'],
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dbimages/17101v.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False}],
#      'postalCode': '22903',
#      'timezone': 'America/New_York',
#      'city': {'name': 'Charlottesville'},
#      'state': {'name': 'Virginia', 'stateCode': 'VA'},
#      'country': {'name': 'United States Of America', 'countryCode': 'US'},
#      'address': {'line1': '295 Massie Rd.'},
#      'location': {'longitude': '-78.5066485', 'latitude': '38.0458774'},
#      'markets': [{'name': 'Virginia', 'id': '46'}],
#      'dmas': [{'id': 246},
#       {'id': 295},
#       {'id': 346},
#       {'id': 369},
#       {'id': 370},
#       {'id': 401}],
#      'social': {'twitter': {'handle': '@JPJArena'}},
#      'boxOfficeInfo': {'phoneNumberDetail': '(434) 924-3537 (Box Office)',
#       'openHoursDetail': 'In Advance : Monday-Friday 10am - 2pm Day of Event : varies',
#       'acceptedPaymentDetail': 'Cash, Visa, Mastercard, Discover, American Express',
#       'willCallDetail': 'Location : box office window 1-3 Opens : same hours as box office Photo ID required.'},
#      'parkingDetail': 'Location : Arena surface lot, Arena garage, and around adjacent University Hall for select events Charge : varies',
#      'accessibleSeatingDetail': 'This is an accessible venue. Accessible Parking : Parking for guests with disabilities is located on level three (the exposed portion) of the parking garage adjacent to the Arena. Accessible parking available on a first come, first served basis. Event parking passes and state issued disabled parking permits are required to access these spaces. Accessible drop-off locations are located along the John Paul Jones Arena side of Massie Road between Emmet Street and Copeley Road. Convenient wheelchair access to John Paul Jones Arena is available at the Main Entrance (West Gate). Public elevators are located on the concourse adjacent to sections 101, 109, 301, and 309. Charge : varies',
#      'generalInfo': {'generalRule': 'John Paul Jones Arena Entry Procedures and Bag Policy Screening procedures are used at all entry gates to John Paul Jones Arena. Walk-through and hand wand metal detectors are the primary means of screening. For guests who are unable to utilize a walk-through metal detector, hand-held metal detectors will be used. • Bags must be clear plastic, vinyl or PVC and cannot exceed 12" x 6" x 12" or clear one-gallon plastic freezer bags (Ziploc bag or similar) are also permitted. • Small clutch bags, approximately the size of a hand and no larger than 4.5" x 6.5" (with or without a handle or strap) can be taken into the stadium or arena and will be subject to search. • An exception will be made for items necessary for medical reasons after proper inspections at a gate designated for this purpose. • Items needed for small children must be in a clear bag that meet the stated dimensions. List of Prohibited Items:(Subject to change) • Bags or Backpacks larger than 12” x 12” x 6” – smaller bags must be clear/see through, with the exception of bags smaller than 4.5” x 6.5” (about the size of a hand) • Weapons, Fireworks or Confetti of any kind • Professional Cameras, Tablets or Computers • Aerosol containers • Umbrellas • Noisemakers or other distracting devices • Balls, Balloons, Frisbees, Sticks and similar items • Audio or Video Recording Devices • Outside Food and Beverage • Strollers • Containers, specifically including glass or plastic bottles, cans, coolers or flasks • Laser Pens/Pointers • Illegal Substances • Animals, except trained service animals • Signs, Flags and Banners of any kind',
#       'childRule': 'Children less than 1 year of age are free'},
#      'upcomingEvents': {'_total': 46,
#       'tmr': 35,
#       'ticketmaster': 11,
#       '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAF6IAA?locale=en-us'}}}],
#    'attractions': [{'name': 'Hot Wheels Crash Zone Pre-Party',
#      'type': 'attraction',
#      'id': 'K8vZ917_sZ0',
#      'test': False,
#      'url': 'https://www.ticketmaster.com/hot-wheels-crash-zone-preparty-tickets/artist/2800762',
#      'locale': 'en-us',
#      'images': [{'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_LANDSCAPE_16_9.jpg',
#        'width': 1136,
#        'height': 639,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_3_2.jpg',
#        'width': 640,
#        'height': 427,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_3_2.jpg',
#        'width': 1024,
#        'height': 683,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#        'width': 2048,
#        'height': 1152,
#        'fallback': False},
#       {'ratio': '4_3',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_CUSTOM.jpg',
#        'width': 305,
#        'height': 225,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RECOMENDATION_16_9.jpg',
#        'width': 100,
#        'height': 56,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_EVENT_DETAIL_PAGE_16_9.jpg',
#        'width': 205,
#        'height': 115,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_RETINA_PORTRAIT_16_9.jpg',
#        'width': 640,
#        'height': 360,
#        'fallback': False},
#       {'ratio': '16_9',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_TABLET_LANDSCAPE_16_9.jpg',
#        'width': 1024,
#        'height': 576,
#        'fallback': False},
#       {'ratio': '3_2',
#        'url': 'https://s1.ticketm.net/dam/a/272/bf44b831-b34c-4613-9fd1-5c1b7e8e9272_1692561_ARTIST_PAGE_3_2.jpg',
#        'width': 305,
#        'height': 203,
#        'fallback': False}],
#      'classifications': [{'primary': True,
#        'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#        'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#        'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#        'type': {'id': 'KZAyXgnZfZ7v7nJ', 'name': 'Upsell'},
#        'subType': {'id': 'KZFzBErXgnZfZ7v7lv', 'name': 'Special Entry'},
#        'family': False}],
#      'upcomingEvents': {'_total': 7, 'ticketmaster': 7, '_filtered': 0},
#      '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917_sZ0?locale=en-us'}}}]}}]

# %%
# Narrowing down the events by name with informative error message if operation is not possible (Directions: Click "Run" to get all the names of the events occuring at your inputed zipcode)
event_names = []
for i in range(0, len(events)):
    try:
        event_names.append(events[i]['name'])
    except IndexError:
        raise IndexError("ID is not properly defined for this zipcode. Please input a new zipcode and try again.")
event_names
# Out:
# ['Reba McEntire',
#  'Trans-Siberian Orchestra - The Ghosts Of Christmas Eve',
#  'MercyMe X Chris Tomlin',
#  'Baby Shark Live! 2022 Splash Tour',
#  'Hot Wheels Monster Trucks Live Glow Party',
#  'Hot Wheels Monster Trucks Live Glow Party',
#  'Hot Wheels Monster Trucks Live Glow Party',
#  'Virginia Cavaliers Football vs. North Carolina Tar Heels Football',
#  'Virginia Cavaliers Football vs. Pittsburgh Panthers Football',
#  'Virginia Cavaliers Football vs. Coastal Carolina Chanticleers Football',
#  'Harlem Globetrotters',
#  'Hot Wheels Crash Zone Pre-Party From 12:00pm-1:15pm',
#  'Hot Wheels Crash Zone Pre-Party From 5:00pm-6:15pm',
#  'Hot Wheels Crash Zone Pre-Party From 10:00am-11:15am']

# %%
# Narrowing down events by date with informative error message if operation is not possible (Directions: Click "Run" to get all the dates of the events occuring at your inputed zipcode)
event_date = []
for i in range(0, len(events)):
    try:
        event_date.append(events[i]['dates']['start']['localDate'])
    except IndexError:
        raise IndexError("ID is not properly defined for this zipcode. Please input a new zipcode and try again.")
event_date
# Out:
# ['2023-03-11',
#  '2022-12-15',
#  '2022-12-02',
#  '2022-11-01',
#  '2023-03-25',
#  '2023-03-25',
#  '2023-03-26',
#  '2022-11-05',
#  '2022-11-12',
#  '2022-11-19',
#  '2023-03-27',
#  '2023-03-26',
#  '2023-03-25',
#  '2023-03-25']

# %%
# Narrowing down events by id with informative error message if operation is not possible (Directions: Click "Run" to get all the ID's of the events occuring at your inputed zipcode)
event_id = []
for i in range(0, len(events)):
    try:
        event_id.append(events[i]['id'])
    except IndexError:
        raise IndexError("ID is not properly defined for this zipcode. Please input a new zipcode and try again.")
event_id
# Out:
# ['vvG17Z9KDKVtwJ',
#  'vvG17Z93kRyd7Y',
#  'vvG17Z9KMmO4z2',
#  'vvG17Z9CTlj6yF',
#  'vvG17Z98NPGgJP',
#  'vvG17Z98NPCAJs',
#  'vvG17Z98NP24JX',
#  'Z7r9jZ1AdC7-I',
#  'Z7r9jZ1AdC7-s',
#  'Z7r9jZ1Aduf7a',
#  'vvG17Z94pt9e9T',
#  'vvG17Z9o66NNB_',
#  'vvG17Z9o66NdyX',
#  'vvG17Z9o66xNys']

# %%
# Creating the dictionary with just event name, id, and date (Directions: Click "Run" to build a dictionary containing the desired event information)
dictionary = {"Name": event_names,
              "ID": event_id,
              "Date": event_date}
dictionary
# Out:
# {'Name': ['Reba McEntire',
#   'Trans-Siberian Orchestra - The Ghosts Of Christmas Eve',
#   'MercyMe X Chris Tomlin',
#   'Baby Shark Live! 2022 Splash Tour',
#   'Hot Wheels Monster Trucks Live Glow Party',
#   'Hot Wheels Monster Trucks Live Glow Party',
#   'Hot Wheels Monster Trucks Live Glow Party',
#   'Virginia Cavaliers Football vs. North Carolina Tar Heels Football',
#   'Virginia Cavaliers Football vs. Pittsburgh Panthers Football',
#   'Virginia Cavaliers Football vs. Coastal Carolina Chanticleers Football',
#   'Harlem Globetrotters',
#   'Hot Wheels Crash Zone Pre-Party From 12:00pm-1:15pm',
#   'Hot Wheels Crash Zone Pre-Party From 5:00pm-6:15pm',
#   'Hot Wheels Crash Zone Pre-Party From 10:00am-11:15am'],
#  'ID': ['vvG17Z9KDKVtwJ',
#   'vvG17Z93kRyd7Y',
#   'vvG17Z9KMmO4z2',
#   'vvG17Z9CTlj6yF',
#   'vvG17Z98NPGgJP',
#   'vvG17Z98NPCAJs',
#   'vvG17Z98NP24JX',
#   'Z7r9jZ1AdC7-I',
#   'Z7r9jZ1AdC7-s',
#   'Z7r9jZ1Aduf7a',
#   'vvG17Z94pt9e9T',
#   'vvG17Z9o66NNB_',
#   'vvG17Z9o66NdyX',
#   'vvG17Z9o66xNys'],
#  'Date': ['2023-03-11',
#   '2022-12-15',
#   '2022-12-02',
#   '2022-11-01',
#   '2023-03-25',
#   '2023-03-25',
#   '2023-03-26',
#   '2022-11-05',
#   '2022-11-12',
#   '2022-11-19',
#   '2023-03-27',
#   '2023-03-26',
#   '2023-03-25',
#   '2023-03-25']}

# %%
# Converting dictionary to a proper JSON string (Directions: Click "Run" to convert the previosuly made dictionary to a proper JSON string that can later be read into a Dataframe)
json_data = json.dumps(dictionary)
json_data
# Out:
# '{"Name": ["Reba McEntire", "Trans-Siberian Orchestra - The Ghosts Of Christmas Eve", "MercyMe X Chris Tomlin", "Baby Shark Live! 2022 Splash Tour", "Hot Wheels Monster Trucks Live Glow Party", "Hot Wheels Monster Trucks Live Glow Party", "Hot Wheels Monster Trucks Live Glow Party", "Virginia Cavaliers Football vs. North Carolina Tar Heels Football", "Virginia Cavaliers Football vs. Pittsburgh Panthers Football", "Virginia Cavaliers Football vs. Coastal Carolina Chanticleers Football", "Harlem Globetrotters", "Hot Wheels Crash Zone Pre-Party From 12:00pm-1:15pm", "Hot Wheels Crash Zone Pre-Party From 5:00pm-6:15pm", "Hot Wheels Crash Zone Pre-Party From 10:00am-11:15am"], "ID": ["vvG17Z9KDKVtwJ", "vvG17Z93kRyd7Y", "vvG17Z9KMmO4z2", "vvG17Z9CTlj6yF", "vvG17Z98NPGgJP", "vvG17Z98NPCAJs", "vvG17Z98NP24JX", "Z7r9jZ1AdC7-I", "Z7r9jZ1AdC7-s", "Z7r9jZ1Aduf7a", "vvG17Z94pt9e9T", "vvG17Z9o66NNB_", "vvG17Z9o66NdyX", "vvG17Z9o66xNys"], "Date": ["2023-03-11", "2022-12-15", "2022-12-02", "2022-11-01", "2023-03-25", "2023-03-25", "2023-03-26", "2022-11-05", "2022-11-12", "2022-11-19", "2023-03-27", "2023-03-26", "2023-03-25", "2023-03-25"]}'

# %%
# Loading the JSON into a Dataframe (Directions: Click "Run" to read the proper JSON string into a DataFrame)
df = pd.read_json(json_data)
df
# Out:
#                                                  Name              ID  \
# 0                                       Reba McEntire  vvG17Z9KDKVtwJ
# 1   Trans-Siberian Orchestra - The Ghosts Of Chris...  vvG17Z93kRyd7Y
# 2                              MercyMe X Chris Tomlin  vvG17Z9KMmO4z2
# 3                   Baby Shark Live! 2022 Splash Tour  vvG17Z9CTlj6yF
# 4           Hot Wheels Monster Trucks Live Glow Party  vvG17Z98NPGgJP
# 5           Hot Wheels Monster Trucks Live Glow Party  vvG17Z98NPCAJs
# 6           Hot Wheels Monster Trucks Live Glow Party  vvG17Z98NP24JX
# 7   Virginia Cavaliers Football vs. North Carolina...   Z7r9jZ1AdC7-I
# 8   Virginia Cavaliers Football vs. Pittsburgh Pan...   Z7r9jZ1AdC7-s
# 9   Virginia Cavaliers Football vs. Coastal Caroli...   Z7r9jZ1Aduf7a
# 10                               Harlem Globetrotters  vvG17Z94pt9e9T
# 11  Hot Wheels Crash Zone Pre-Party From 12:00pm-1...  vvG17Z9o66NNB_
# 12  Hot Wheels Crash Zone Pre-Party From 5:00pm-6:...  vvG17Z9o66NdyX
# 13  Hot Wheels Crash Zone Pre-Party From 10:00am-1...  vvG17Z9o66xNys
#
#          Date
# 0  2023-03-11
# 1  2022-12-15
# 2  2022-12-02
# 3  2022-11-01
# 4  2023-03-25
# 5  2023-03-25
# 6  2023-03-26
# 7  2022-11-05
# 8  2022-11-12
# 9  2022-11-19
# 10 2023-03-27
# 11 2023-03-26
# 12 2023-03-25
# 13 2023-03-25

# %%
# Converting df to a CSV and writing it to a local file (Directions: Click "Run" to convert the DataFrame to a CSV and save that as a local file called "out.csv")
df.to_csv('out.csv', index=False)
